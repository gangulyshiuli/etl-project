# %% [markdown]
# ### TedTalks

# %%
# import dependencies

import pandas as pd
from sqlalchemy import create_engine
from config import username, password

# %%
# Ted Talks
TED_Talks_query = 'TedTalks/QueryResult.csv'
tedtalks = pd.read_csv(TED_Talks_query)

# %% [markdown]
# ### Create a DataBase Called: ETL_db. Create a Table called: tt_table

# %%
conn = "postgres:postgres@localhost:5432/ETL_db"

# %%
engine = create_engine(f'postgresql://{conn}')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-70-dfea8d1efc6a> in <module>
# ----> 1 engine = create_engine(f'postgresql://{conn}')
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     477     strategy = kwargs.pop("strategy", default_strategy)
#     478     strategy = strategies.strategies[strategy]
# --> 479     return strategy.create(*args, **kwargs)
#     480
#     481
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
#      89         dialect_args["dbapi"] = dbapi
#
# ...

# %%
from sqlalchemy import create_engine
from config import username, password
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432')
con = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-71-2cb260107729> in <module>
#       1 from sqlalchemy import create_engine
#       2 from config import username, password
# ----> 3 engine = create_engine(f'postgresql://{username}:{password}@localhost:5432')
#       4 con = engine.connect()
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     477     strategy = kwargs.pop("strategy", default_strategy)
#     478     strategy = strategies.strategies[strategy]
# --> 479     return strategy.create(*args, **kwargs)
#     480
#     481
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ...

# %%
TED_Talks_More_load = "Tedtalks/TED_Talks_more.csv"
tedtalks_more = pd.read_csv(TED_Talks_More_load)

# %%
tedtalks.head()
# Out:
#    id       speaker                              headline  \
# 0   1       Al Gore           Averting the climate crisis
# 1   2     Amy Smith         Simple designs to save a life
# 2   3  Ashraf Ghani         How to rebuild a broken state
# 3   4    Burt Rutan  The real future of space exploration
# 4   5  Chris Bangle              Great cars are great art
#
#                                   url  \
# 0  http://www.ted.com/talks/view/id/1
# 1  http://www.ted.com/talks/view/id/2
# 2  http://www.ted.com/talks/view/id/3
# 3  http://www.ted.com/talks/view/id/4
# 4  http://www.ted.com/talks/view/id/5
#
#                                          description  \
# 0  With the same humor and humanity he exuded in ...
# 1  Fumes from indoor cooking fires kill more than...
# 2  Ashraf Ghani's passionate and powerful 10-minu...
# 3  In this passionate talk, legendary spacecraft ...
# 4  American designer Chris Bangle explains his ph...
#
# ...

# %%
tedtalks.shape
# Out:
# (2475, 12)

# %%
tedtalks.dtypes
# Out:
# id                 int64
# speaker           object
# headline          object
# url               object
# description       object
# transcript_url    object
# month_filmed       int64
# year_filmed        int64
# event             object
# duration          object
# date_published    object
# tags              object
# dtype: object

# %% [markdown]
# DROP TABLE IF EXISTS tt_table;
# CREATE TABLE tt_table(
#     tt_id integer NOT NULL,
#     tt_speaker character varying(255) NOT NULL,
#     tt_headline character varying(255) NOT NULL,
#     tt_url character varying (255) NOT NULL,
#     tt_desc character varying NOT NULL,
#     tt_transcript character varying(255),
#     tt_month_filmed integer,
#     tt_year_filmed integer,
#     tt_event character varying(255),
#     tt_duration character varying(8),
#     tt_date_published DATE,
#     tt_tags character varying NOT NULL
# );
# COPY tt_table FROM '/Applications/PostgreSQL 12/etl_data/data/QueryResult.csv' DELIMITER ',' CSV HEADER;
# SELECT * FROM tt_table;

# %%
for col_name in tedtalks.columns:
    print(col_name)
# Out:
# id
# speaker
# headline
# url
# description
# transcript_url
# month_filmed
# year_filmed
# event
# duration
# date_published
# tags

# %%
tedtalks.tags
# Out:
# 0       cars,alternative energy,culture,politics,scien...
# 1       MacArthur grant,simplicity,industrial design,a...
# 2       corruption,poverty,economics,investment,milita...
# 3       aircraft,flight,industrial design,NASA,rocket ...
# 4       cars,industrial design,transportation,inventio...
#                               ...
# 2470    autism spectrum disorder,TED en espanol,TEDx,a...
# 2471    AI,algorithm,brain,cognitive science,machine l...
# 2472    Christianity,God,aging,art,beauty,birds,books,...
# 2473    choice,fear,goal-setting,humanity,life,persona...
# 2474    adventure,collaboration,demo,design,engineerin...
# Name: tags, Length: 2475, dtype: object

# %%
tedtalks_more.shape
# Out:
# (2475, 123)

# %%
for col_name in tedtalks.columns: 
    print(col_name)
# Out:
# id
# speaker
# headline
# url
# description
# transcript_url
# month_filmed
# year_filmed
# event
# duration
# date_published
# tags

# %%
tedtalks.tags
tedtalks_more.dtypes
tedtalks_more.columns
for col_name in tedtalks_more.columns: 
    print(col_name)
# Out:
# id
# speaker
# headline
# URL
# description
# transcript_URL
# month_filmed
# year_filmed
# event
# duration
# date_published
# views_as_of_06162017
# tags
# transcript
# notes
# WC
# Analytic
# Clout
# Authentic
# Tone
# WPS
# Sixltr
# Dic
# function
# pronoun
# ppron
# i
# we
# you
# shehe
# they
# ipron
# article
# prep
# auxverb
# adverb
# conj
# negate
# verb
# adj
# compare
# interrog
# number
# quant
# affect
# posemo
# negemo
# anx
# anger
# sad
# social
# family
# friend
# female
# male
# cogproc
# insight
# cause
# discrep
# tentat
# certain
# differ
# percept
# see
# hear
# feel
# bio
# body
# health
# sexual
# ingest
# drives
# affiliation
# achieve
# power
# reward
# risk
# focuspast
# focuspresent
# focusfuture
# relativ
# motion
# space
# time
# work
# leisure
# home
# money
# relig
# death
# informal
# swear
# netspeak
# assent
# nonflu
# filler
# AllPunc
# Period
# Comma
# Colon
# SemiC
# QMark
# Exclam
# Dash
# Quote
# Apostro
# Parenth
# OtherP
# WC2
# WPS.1
# ...

# %%
tedtalks_more.dtypes
# Out:
# id                    int64
# speaker              object
# headline             object
# URL                  object
# description          object
#                      ...
# authority_virtue    float64
# authority_vice      float64
# purity_virtue       float64
# purity_vice         float64
# morality_general    float64
# Length: 123, dtype: object

# %%
tedtalks_more.columns
# Out:
# Index(['id', 'speaker', 'headline', 'URL', 'description', 'transcript_URL',
#        'month_filmed', 'year_filmed', 'event', 'duration',
#        ...
#        'harm_vice', 'fairness_virtue', 'fairness_vice', 'ingroup_virtue',
#        'ingroup_vice', 'authority_virtue', 'authority_vice', 'purity_virtue',
#        'purity_vice', 'morality_general'],
#       dtype='object', length=123)

# %%
for col_name in tedtalks_more.columns: 
    print(col_name)
# Out:
# id
# speaker
# headline
# URL
# description
# transcript_URL
# month_filmed
# year_filmed
# event
# duration
# date_published
# views_as_of_06162017
# tags
# transcript
# notes
# WC
# Analytic
# Clout
# Authentic
# Tone
# WPS
# Sixltr
# Dic
# function
# pronoun
# ppron
# i
# we
# you
# shehe
# they
# ipron
# article
# prep
# auxverb
# adverb
# conj
# negate
# verb
# adj
# compare
# interrog
# number
# quant
# affect
# posemo
# negemo
# anx
# anger
# sad
# social
# family
# friend
# female
# male
# cogproc
# insight
# cause
# discrep
# tentat
# certain
# differ
# percept
# see
# hear
# feel
# bio
# body
# health
# sexual
# ingest
# drives
# affiliation
# achieve
# power
# reward
# risk
# focuspast
# focuspresent
# focusfuture
# relativ
# motion
# space
# time
# work
# leisure
# home
# money
# relig
# death
# informal
# swear
# netspeak
# assent
# nonflu
# filler
# AllPunc
# Period
# Comma
# Colon
# SemiC
# QMark
# Exclam
# Dash
# Quote
# Apostro
# Parenth
# OtherP
# WC2
# WPS.1
# ...

# %% [markdown]
# ### Selecting Columns from 123 columns

# %%
select_columns = {"headline", "number", "id", "speaker", "description", "views_as_of_06162017", "tags", "Clout", "date_published", "duration"}

# %%
tedtalks_more[select_columns]
# Out:
#      duration                                        description  \
# 0     0:16:17  With the same humor and humanity he exuded in ...
# 1     0:15:06  Fumes from indoor cooking fires kill more than...
# 2     0:18:45  Ashraf Ghani's passionate and powerful 10-minu...
# 3     0:19:37  In this passionate talk, legendary spacecraft ...
# 4     0:20:04  American designer Chris Bangle explains his ph...
# ...       ...                                                ...
# 2470  0:12:39  There's a creepy transformation taking over ou...
# 2471  0:06:32  Attention isn't just about what we focus on  i...
# 2472  0:13:21  The hard choices  what we most fear doing, ask...
# 2473  0:15:55  A few days before she turned 61, writer Anne L...
# 2474  0:07:08  We've all dreamed of flying  but for Richard B...
#
#      date_published  number  \
# 0           6/27/06    6.97
# 1           8/15/06    4.88
# 2          10/18/06    5.03
# 3          10/25/06    5.37
# 4            4/5/07    3.07
# ...

# %%
tedtalks_more.views_as_of_06162017
# Out:
# 0       3177001.0
# 1       1379328.0
# 2        790536.0
# 3       1985119.0
# 4        859487.0
#           ...
# 2470     519418.0
# 2471     422132.0
# 2472     582001.0
# 2473     651425.0
# 2474     323733.0
# Name: views_as_of_06162017, Length: 2475, dtype: float64

# %% [markdown]
# ### For every tag catch a list of Indices of TedTalks with tag in tags

# %% [markdown]
# ## Enter search word here (default music)

# %%
search_tag = " MuSic "

# %%
search_tag = " MuSic "
clean_tag = search_tag.lower()
clean_tag = clean_tag.lstrip()
clean_tag = clean_tag.rstrip()
print(f"For Search Tag {search_tag} the clean version is {clean_tag}")
# Out:
# For Search Tag  MuSic  the clean version is music

# %%
TedTalks_set = set()
TedTalks_match = []
TedTalks_Tags = []
match_found = 0
index=-1

for tag in tedtalks.tags:
    index+=1
    get_tag = tag
    tag_list = tag.split(",")
    get_index = index
    for tag in tag_list:
        fix_tag = tag.lower()
        fix_tag = fix_tag.lstrip()
        fix_tag = fix_tag.rstrip()
        if (clean_tag == fix_tag):
            TedTalks_match.append(get_index)
            TedTalks_Tags.append(get_tag)
            match_found +=1

# %%
match_found
print(f"The word searched was {search_tag}. \nNumber of Matches Found for {clean_tag} are {match_found}")
# Out:
# The word searched was  MuSic .
# Number of Matches Found for music are 138

# %% [markdown]
# ### Search Results

# %%
print(f"The search word was: {search_tag} \nMatches found {match_found} \n")
if (match_found>0):
    print(f"{match_found} Ted Talk TAGS that matched are: \n \n")
    for tag in TedTalks_Tags:
          print(f"{tag}\n")
# Out:
# The search word was:  MuSic
# Matches found 138
#
# 138 Ted Talk TAGS that matched are:
#
#
# simplicity,computers,software,interface design,music,media,entertainment,performance,technology
#
# invention,software,music,entertainment,performance,technology,art
#
# TED Brain Trust,film,culture,music,activism,social change,storytelling,global issues,collaboration,art
#
# violin,wunderkind,youth,music,entertainment,performance
#
# wunderkind,music,piano,entertainment,performance,creativity
#
# poetry,live music,music,singer,entertainment,performance
#
# guitar,music,vocals,climate change,environment,performance
#
# cello,music,vocals,entertainment,performance
#
# live music,music,entertainment,performance,creativity
#
# guitar,performance art,composing,music,piano,vocals,potential,entertainment,performance
#
# memory,guitar,composing,music,piano,entertainment,performance
#
# live music,music,entertainment,performance
#
# violin,live music,music,history,entertainment,performance
#
# ...

# %% [markdown]
# ### Given Search Word

# %%
clean_tag = search_tag.lower()
clean_tag = clean_tag.lstrip()
clean_tag = clean_tag.rstrip()
print(f"For Search Tag {search_tag} the clean version is {clean_tag}")

TedTalks_set = set()
TedTalks_match = []
TedTalks_Tags = []
match_found = 0
index=-1

for tag in tedtalks.tags:
    index+=1
    get_tag = tag
    tag_list = tag.split(",")
    get_index = index
    for tag in tag_list:
        fix_tag = tag.lower()
        fix_tag = fix_tag.lstrip()
        fix_tag = fix_tag.rstrip()
        if (clean_tag == fix_tag):
            TedTalks_match.append(get_index)
            TedTalks_Tags.append(get_tag)
            match_found +=1
    

print(f"The search word was: {search_tag}: Matches found {match_found} \n")
if (match_found>0):
    print(f"{match_found} The Ted Talks Tags that matched are: \n")
    for tag in TedTalks_Tags:
          print(tag)
            
            
if (match_found==0):
    print(f"Sorry. No Matches found for {search_tag}")
# Out:
# For Search Tag  MuSic  the clean version is music
# The search word was:  MuSic : Matches found 138
#
# 138 The Ted Talks Tags that matched are:
#
# simplicity,computers,software,interface design,music,media,entertainment,performance,technology
# invention,software,music,entertainment,performance,technology,art
# TED Brain Trust,film,culture,music,activism,social change,storytelling,global issues,collaboration,art
# violin,wunderkind,youth,music,entertainment,performance
# wunderkind,music,piano,entertainment,performance,creativity
# poetry,live music,music,singer,entertainment,performance
# guitar,music,vocals,climate change,environment,performance
# cello,music,vocals,entertainment,performance
# live music,music,entertainment,performance,creativity
# guitar,performance art,composing,music,piano,vocals,potential,entertainment,performance
# memory,guitar,composing,music,piano,entertainment,performance
# live music,music,entertainment,performance
# ...

# %%
TedTalks_Tags
# Out:
# ['simplicity,computers,software,interface design,music,media,entertainment,performance,technology',
#  'invention,software,music,entertainment,performance,technology,art',
#  'TED Brain Trust,film,culture,music,activism,social change,storytelling,global issues,collaboration,art',
#  'violin,wunderkind,youth,music,entertainment,performance',
#  'wunderkind,music,piano,entertainment,performance,creativity',
#  'poetry,live music,music,singer,entertainment,performance',
#  'guitar,music,vocals,climate change,environment,performance',
#  'cello,music,vocals,entertainment,performance',
#  'live music,music,entertainment,performance,creativity',
#  'guitar,performance art,composing,music,piano,vocals,potential,entertainment,performance',
#  'memory,guitar,composing,music,piano,entertainment,performance',
#  'live music,music,entertainment,performance',
#  'violin,live music,music,history,entertainment,performance',
# ...

# %%
TedTalks_match
# Out:
# [6,
#  13,
#  20,
#  42,
#  43,
#  77,
#  93,
#  94,
#  96,
#  100,
#  101,
#  105,
#  107,
#  109,
#  139,
#  148,
#  158,
#  163,
#  165,
#  173,
#  195,
#  215,
#  219,
#  227,
#  231,
#  235,
#  251,
#  254,
#  257,
#  259,
#  275,
#  278,
#  282,
#  294,
#  310,
#  312,
#  344,
#  372,
#  377,
#  380,
#  381,
#  393,
#  441,
#  442,
#  453,
#  468,
#  493,
#  506,
#  511,
#  531,
#  534,
#  541,
#  571,
#  576,
#  588,
#  600,
#  624,
#  649,
#  661,
#  667,
#  681,
#  699,
#  700,
#  705,
#  710,
#  715,
#  766,
#  772,
#  778,
#  792,
#  798,
#  808,
#  843,
#  852,
#  869,
#  879,
#  899,
#  904,
#  911,
#  964,
#  965,
#  1003,
#  1032,
#  1080,
#  1087,
#  1111,
#  1119,
#  1145,
#  1177,
#  1205,
#  1225,
#  1231,
#  1243,
#  1282,
#  1285,
#  1291,
#  1304,
#  1350,
#  1448,
#  1513,
#  1544,
#  1554,
#  1566,
#  1570,
#  1657,
#  1662,
#  1677,
#  1716,
#  1743,
#  1759,
#  1782,
#  1801,
#  1837,
#  1866,
#  1882,
#  1969,
#  1975,
#  1977,
#  1994,
#  2064,
#  2068,
# ...

# %%
tedtalks.head()
# Out:
#    id       speaker                              headline  \
# 0   1       Al Gore           Averting the climate crisis
# 1   2     Amy Smith         Simple designs to save a life
# 2   3  Ashraf Ghani         How to rebuild a broken state
# 3   4    Burt Rutan  The real future of space exploration
# 4   5  Chris Bangle              Great cars are great art
#
#                                   url  \
# 0  http://www.ted.com/talks/view/id/1
# 1  http://www.ted.com/talks/view/id/2
# 2  http://www.ted.com/talks/view/id/3
# 3  http://www.ted.com/talks/view/id/4
# 4  http://www.ted.com/talks/view/id/5
#
#                                          description  \
# 0  With the same humor and humanity he exuded in ...
# 1  Fumes from indoor cooking fires kill more than...
# 2  Ashraf Ghani's passionate and powerful 10-minu...
# 3  In this passionate talk, legendary spacecraft ...
# 4  American designer Chris Bangle explains his ph...
#
# ...

# %%
all_tedtalks_tags = tedtalks_more.tags
for tag in all_tedtalks_tags:
    print(tag)
# Out:
# cars,alternative energy,culture,politics,science,climate change,environment,sustainability,global issues,technology
# MacArthur grant,simplicity,industrial design,alternative energy,invention,engineering,design,global issues
# corruption,poverty,economics,investment,military,culture,politics,policy,global development,entrepreneur,global issues,business
# aircraft,flight,industrial design,NASA,rocket science,invention,engineering,entrepreneur,design,business
# cars,industrial design,transportation,invention,design,technology,business,art
# biotech,invention,oceans,genetics,DNA,biology,science,entrepreneur,biodiversity,ecology,technology
# simplicity,computers,software,interface design,music,media,entertainment,performance,technology
# New York,memory,interview,death,culture,architecture,disaster relief,cities,urban planning,design,collaboration
# robots,cars,industrial design,transportation,invention,education,innovation,social change,science,sustainability,technology,business
# ...

# %%
keyword_list = tag.split(",")

# %%
keyword_list
# Out:
# ['adventure',
#  'collaboration',
#  'demo',
#  'design',
#  'engineering',
#  'entrepreneur',
#  'flight',
#  'future',
#  'innovation',
#  'invention',
#  'motivation',
#  'potential',
#  'technology']

# %%
keyword_list[-1]
# Out:
# 'technology'

# %% [markdown]
# ### TedTalks_keyword_set

# %% [markdown]
# ### Finding ALL the Key Words in Ted Talk from Ted Talk Tags

# %%
TedTalks_keyword_set = set()
for tag in all_tedtalks_tags:
    keyword_list = tag.split(",")
    for keyword in keyword_list:
        if (keyword):
            TedTalks_keyword_set.add(keyword)
    
print(TedTalks_keyword_set)
# Out:
# {'nature', 'dance', 'Asia', 'war', 'telecom', 'oceans', 'art', 'alternative energy', 'sex', 'pregnancy', 'blockchain', ' personality', 'choice', 'microsoft', 'virtual reality', '3D printing', 'youth', ' violence', 'film', 'literature', 'crowdsourcing', ' life', 'complexity', 'democracy', ' Communication', 'biotech', 'data', 'bullying', 'Brand', 'TED Brain Trust', 'men', 'heart health', 'disability', 'architecture', 'family', 'philosophy', 'map', 'illusion', 'education', 'industrial design', 'trust', 'Syria', 'behavioral economics', ' technology', 'suicide', 'deextinction', 'natural disaster', ' humanity', ' Community', 'history', 'resources', 'gender spectrum', 'environment', 'criminal justice', 'planets', 'disease', 'online video', ' singer', 'cognitive science', 'guitar', ' math', 'Latin America', 'social change', 'insects', 'big problems', 'natural resources', 'genetics', 'mission blue', 'hearing', 'poverty', 'entrepreneur', 'children', 'medical imaging', 'South America', ' perfor
# ...

# %%
search_terms = []
for word in TedTalks_keyword_set:
    lower_case = word.lower()
    no_spaces_left = lower_case.lstrip()
    no_spaces = no_spaces_left.rstrip()
    search_terms.append(no_spaces)
    
search_terms.sort()
search_terms_set = set()
for word in search_terms:
    search_terms_set.add(word)
    
sorted_terms = []
for word in search_terms_set:
    sorted_terms.append(word)
    
sorted_terms.sort()
sorted_terms
# Out:
# ['3d printing',
#  'activism',
#  'addiction',
#  'adventure',
#  'advertising',
#  'africa',
#  'aging',
#  'agriculture',
#  'ai',
#  'aids',
#  'aircraft',
#  'algorithm',
#  'alternative energy',
#  "alzheimer's",
#  'ancient world',
#  'animals',
#  'animation',
#  'anthropocene',
#  'anthropology',
#  'ants',
#  'apes',
#  'archaeology',
#  'architecture',
#  'art',
#  'arts',
#  'asia',
#  'asteroid',
#  'astronomy',
#  'atheism',
#  'augmented reality',
#  'autism spectrum disorder',
#  'bacteria',
#  'beauty',
#  'bees',
#  'behavioral economics',
#  'big bang',
#  'big problems',
#  'biodiversity',
#  'bioethics',
#  'biology',
#  'biomechanics',
#  'biomimicry',
#  'biosphere',
#  'biotech',
#  'birds',
#  'blockchain',
#  'body language',
#  'books',
#  'botany',
#  'brain',
#  'brand',
#  'brazil',
#  'buddhism',
#  'bullying',
#  'business',
#  'cancer',
#  'capitalism',
#  'cars',
#  'cello',
#  'charter for compassion',
#  'chemistry',
#  'children',
#  'china',
# ...

# %%
search_terms.sort()
search_terms_set = set()
for word in search_terms:
    search_terms_set.add(word)
    
sorted_terms = []
for word in search_terms_set:
    sorted_terms.append(word)

# %%
All_TedTalk_Tags = sorted_terms

# %%
len(All_TedTalk_Tags)
# Out:
# 417

# %%
len(sorted_terms)
# Out:
# 417

# %%
len(TedTalks_keyword_set)
# Out:
# 508

# %% [markdown]
# ### In this Function: Input is a search word s and RETURNS match_found and List of Ted Talk Tags

# %%
### Here s is a search_word

def find_TedTalks_Tags_list(s):
    #match_found Integer 0 and above
    #TedTalks_Tags is a list
    search_tag = s    
    clean_tag = search_tag.lower()
    clean_tag = clean_tag.lstrip()
    clean_tag = clean_tag.rstrip()
    #print(f"For Search Tag {search_tag} the clean version is {clean_tag}")

    TedTalks_set = set()
    TedTalks_match = []
    TedTalks_Tags = []
    match_found = 0
    index=-1

    for tag in tedtalks.tags:
        index+=1
        get_tag = tag
        tag_list = tag.split(",")
        get_index = index
        for tag in tag_list:
            fix_tag = tag.lower()
            fix_tag = fix_tag.lstrip()
            fix_tag = fix_tag.rstrip()
            if (clean_tag == fix_tag):
                TedTalks_match.append(get_index)
                TedTalks_Tags.append(get_tag)
                match_found +=1
    


    
    return (TedTalks_Tags)

#TedTalks_Tags is a list

# %% [markdown]
# ### In this Function: Input is a search word s and RETURNS matches found and Index of Ted Talk

# %%
#Here s is a search_word

def find_TedTalks_Matched_list(s):
    #match_found Integer 0 and above
    #TedTalks_Tags is a list
    search_tag = s    
    clean_tag = search_tag.lower()
    clean_tag = clean_tag.lstrip()
    clean_tag = clean_tag.rstrip()
    #print(f"For Search Tag {search_tag} the clean version is {clean_tag}")

    TedTalks_set = set()
    TedTalks_match = []
    TedTalks_Tags = []
    match_found = 0
    index=-1

    for tag in tedtalks.tags:
        index+=1
        get_tag = tag
        tag_list = tag.split(",")
        get_index = index
        for tag in tag_list:
            fix_tag = tag.lower()
            fix_tag = fix_tag.lstrip()
            fix_tag = fix_tag.rstrip()
            if (clean_tag == fix_tag):
                TedTalks_match.append(get_index)
                TedTalks_Tags.append(get_tag)
                match_found +=1
    


    
    return (TedTalks_match)

#TedTalks_match is a list of Index

# %% [markdown]
# ### In this Function given a search word s we find how many Tags Matched

# %%
#Here s is a search_word

def TedTalks_Matched(s):
    #match_found Integer 0 and above
    #TedTalks_Tags is a list
    search_tag = s    
    clean_tag = search_tag.lower()
    clean_tag = clean_tag.lstrip()
    clean_tag = clean_tag.rstrip()
    #print(f"For Search Tag {search_tag} the clean version is {clean_tag}")

    TedTalks_set = set()
    TedTalks_match = []
    TedTalks_Tags = []
    match_found = 0
    index=-1

    for tag in tedtalks.tags:
        index+=1
        get_tag = tag
        tag_list = tag.split(",")
        get_index = index
        for tag in tag_list:
            fix_tag = tag.lower()
            fix_tag = fix_tag.lstrip()
            fix_tag = fix_tag.rstrip()
            if (clean_tag == fix_tag):
                TedTalks_match.append(get_index)
                TedTalks_Tags.append(get_tag)
                match_found +=1
    
    print(f"Match Found {match_found}")

    
    return (match_found)

#TedTalks_Matched is an Integer Greater or Equal to ZERO

# %% [markdown]
# ### Given a search word s

# %%
s = " MuSic "

# %%
search_word = s
searched_match_found = TedTalks_Matched(s)
searched_Tags = find_TedTalks_Tags_list(s)
searched_Matched = find_TedTalks_Matched_list(s)
# Out:
# Match Found 138

# %%
if (searched_match_found >0):
    for tag in searched_Tags:
        url = tedtalks.iloc[index][3]
        speaker = tedtalks.iloc[index][1]
        print(f"{tag} \n")
# Out:
# simplicity,computers,software,interface design,music,media,entertainment,performance,technology
#
# invention,software,music,entertainment,performance,technology,art
#
# TED Brain Trust,film,culture,music,activism,social change,storytelling,global issues,collaboration,art
#
# violin,wunderkind,youth,music,entertainment,performance
#
# wunderkind,music,piano,entertainment,performance,creativity
#
# poetry,live music,music,singer,entertainment,performance
#
# guitar,music,vocals,climate change,environment,performance
#
# cello,music,vocals,entertainment,performance
#
# live music,music,entertainment,performance,creativity
#
# guitar,performance art,composing,music,piano,vocals,potential,entertainment,performance
#
# memory,guitar,composing,music,piano,entertainment,performance
#
# live music,music,entertainment,performance
#
# violin,live music,music,history,entertainment,performance
#
# poetry,sports,live music,race,culture,music,entertainment,performance
#
# ...

# %%
if (searched_match_found >0):
    for index in searched_Matched:
        url = tedtalks.iloc[index][3]
        speaker = tedtalks.iloc[index][1]
        print(f"Searched for {s} found {searched_match_found} Matches. Ted Talk {url} by Speaker {speaker}")
# Out:
# Searched for  MuSic  found 138 Matches. Ted Talk http://www.ted.com/talks/view/id/7 by Speaker David Pogue
# Searched for  MuSic  found 138 Matches. Ted Talk http://www.ted.com/talks/view/id/14 by Speaker Golan Levin
# Searched for  MuSic  found 138 Matches. Ted Talk http://www.ted.com/talks/view/id/23 by Speaker Peter Gabriel
# Searched for  MuSic  found 138 Matches. Ted Talk http://www.ted.com/talks/view/id/45 by Speaker Sirena Huang
# Searched for  MuSic  found 138 Matches. Ted Talk http://www.ted.com/talks/view/id/46 by Speaker Jennifer Lin
# Searched for  MuSic  found 138 Matches. Ted Talk http://www.ted.com/talks/view/id/81 by Speaker Nora York
# Searched for  MuSic  found 138 Matches. Ted Talk http://www.ted.com/talks/view/id/99 by Speaker Jill Sobule
# Searched for  MuSic  found 138 Matches. Ted Talk http://www.ted.com/talks/view/id/101 by Speaker Caroline Lavelle
# ...

# %%
for index in searched_Matched:
    tags_matched = tedtalks.iloc[index][11]
    print(f"Searched for {search_word} and found tag: {tags_matched} \n")
# Out:
# Searched for  MuSic  and found tag: simplicity,computers,software,interface design,music,media,entertainment,performance,technology
#
# Searched for  MuSic  and found tag: invention,software,music,entertainment,performance,technology,art
#
# Searched for  MuSic  and found tag: TED Brain Trust,film,culture,music,activism,social change,storytelling,global issues,collaboration,art
#
# Searched for  MuSic  and found tag: violin,wunderkind,youth,music,entertainment,performance
#
# Searched for  MuSic  and found tag: wunderkind,music,piano,entertainment,performance,creativity
#
# Searched for  MuSic  and found tag: poetry,live music,music,singer,entertainment,performance
#
# Searched for  MuSic  and found tag: guitar,music,vocals,climate change,environment,performance
#
# Searched for  MuSic  and found tag: cello,music,vocals,entertainment,performance
#
# Searched for  MuSic  and found tag: live music,music,entertainment,performance,creativity
#
# ...

# %% [markdown]
# ### About to Generate a File. For every word in the List of Basic Key Words, find Matched Tags

# %%
All_TedTalk_Tags
# Out:
# ['nature',
#  'dance',
#  'war',
#  'telecom',
#  'oceans',
#  'art',
#  'alternative energy',
#  'sex',
#  'pregnancy',
#  'blockchain',
#  'choice',
#  'microsoft',
#  'virtual reality',
#  'surgery',
#  'youth',
#  'film',
#  'literature',
#  'crowdsourcing',
#  'complexity',
#  'democracy',
#  'biotech',
#  'bullying',
#  'data',
#  'men',
#  'heart health',
#  'disability',
#  'architecture',
#  'family',
#  'philosophy',
#  'map',
#  'illusion',
#  'education',
#  'industrial design',
#  'trust',
#  'behavioral economics',
#  'suicide',
#  'google',
#  'deextinction',
#  'macarthur grant',
#  'natural disaster',
#  'history',
#  'resources',
#  'gender spectrum',
#  'criminal justice',
#  'environment',
#  'planets',
#  'disease',
#  'online video',
#  'ted fellows',
#  'cognitive science',
#  'guitar',
#  'ted residency',
#  'big problems',
#  'insects',
#  'social change',
#  'natural resources',
#  'genetics',
#  'mission blue',
#  'hearing',
#  'poverty',
# ...

# %%
All_TedTalk_Tags
total_TT_words=len(All_TedTalk_Tags)
print(f"Generated Total Search Words of: {total_TT_words} from Ted Talk Tags")
# Out:
# Generated Total Search Words of: 417 from Ted Talk Tags

# %%
AllSorted_Tags = All_TedTalk_Tags.sort()

# %% [markdown]
# ### For every Search Word, Find The List of Tags Matched

# %% [markdown]
# ## Recall Function find_TedTalks_Tags_list(s)

# %%
TTT_list = []
TTT_dict = {}
for s in All_TedTalk_Tags:
    TTT = find_TedTalks_Tags_list(s) 
    TTT_dict = {s:TTT}
    TTT_list.append(TTT_dict)

# %%
len(TTT_list)
# Out:
# 417

# %%
TTT_list[0]
# Out:
# {'3d printing': ['3D printing,design,technology,business',
#   '3D printing,molecular biology,synthetic biology,chemistry,pharmaceuticals,biotech,invention,software,health care,medicine,medical research,product design,biology,innovation,science,engineering,future,technology',
#   '3D printing,crowdsourcing,biomimicry,biotech,visualizations,science and art,biology,bacteria,science,microbiology,microbes,collaboration,art']}

# %%
Zip_Word_Tags = list(zip(All_TedTalk_Tags, TTT_list))

# %% [markdown]
# ## Creating a DataFrame Word_Tag

# %%
Zip_Word_Tags = list(zip(All_TedTalk_Tags, TTT_list))
Word_Tag_df = pd.DataFrame(Zip_Word_Tags, columns = ["SearchWord", "MatchedTags"])

# %%
Word_Tag_df.head()
# Out:
#     SearchWord                                        MatchedTags
# 0  3d printing  {'3d printing': ['3D printing,design,technolog...
# 1     activism  {'activism': ['TED Brain Trust,film,culture,mu...
# 2    addiction  {'addiction': ['narcotics,addiction,culture,po...
# 3    adventure  {'adventure': ['Moon,mining,Planets,NASA,space...
# 4  advertising  {'advertising': ['advertising,consumerism,happ...

# %%
Word_Tag_df.shape
# Out:
# (417, 2)

# %%
Word_Tag_df.dtypes
# Out:
# SearchWord     object
# MatchedTags    object
# dtype: object

# %%
Word_Tag_df.SearchWord
# Out:
# 0         3d printing
# 1            activism
# 2           addiction
# 3           adventure
# 4         advertising
#             ...
# 412    world cultures
# 413           writing
# 414        wunderkind
# 415       yesallwomen
# 416             youth
# Name: SearchWord, Length: 417, dtype: object

# %%
Word_Tag_df.MatchedTags
# Out:
# 0      {'3d printing': ['3D printing,design,technolog...
# 1      {'activism': ['TED Brain Trust,film,culture,mu...
# 2      {'addiction': ['narcotics,addiction,culture,po...
# 3      {'adventure': ['Moon,mining,Planets,NASA,space...
# 4      {'advertising': ['advertising,consumerism,happ...
#                              ...
# 412    {'world cultures': ['Latin America,love,world ...
# 413    {'writing': ['relationships,parenting,communic...
# 414    {'wunderkind': ['wunderkind,cancer,disease,hea...
# 415    {'yesallwomen': ['yesallwomen,gender,feminism,...
# 416    {'youth': ['violin,wunderkind,youth,music,ente...
# Name: MatchedTags, Length: 417, dtype: object

# %%
Word_Tag_df.to_csv("searchword.csv", index=True)

# %% [markdown]
# ### Create a DataFrame with a MatchesFound Integer Columns

# %%
TTT_list = []
TT_tags = []
TTT_dict = {}
TTT_matches = []
for s in All_TedTalk_Tags:
    TTT = find_TedTalks_Tags_list(s) 
    TTT_match_found = TedTalks_Matched(s)
    TTT_dict = {s:TTT}
    TTT_list.append(TTT_dict)
    TT_tags.append(TTT)
    TTT_matches.append(TTT_match_found)
# Out:
# Match Found 3
# Match Found 149
# Match Found 5
# Match Found 48
# Match Found 10
# Match Found 98
# Match Found 41
# Match Found 34
# Match Found 36
# Match Found 16
# Match Found 7
# Match Found 32
# Match Found 37
# Match Found 1
# Match Found 20
# Match Found 108
# Match Found 16
# Match Found 2
# Match Found 23
# Match Found 3
# Match Found 3
# Match Found 8
# Match Found 78
# Match Found 207
# Match Found 2
# Match Found 26
# Match Found 1
# Match Found 47
# Match Found 5
# Match Found 2
# Match Found 10
# Match Found 25
# Match Found 59
# Match Found 11
# Match Found 22
# Match Found 9
# Match Found 63
# Match Found 62
# Match Found 22
# Match Found 181
# Match Found 27
# Match Found 22
# Match Found 9
# Match Found 71
# Match Found 12
# Match Found 1
# Match Found 11
# Match Found 36
# Match Found 15
# Match Found 154
# Match Found 3
# Match Found 10
# Match Found 8
# Match Found 7
# Match Found 341
# Match Found 45
# Match Found 10
# Match Found 20
# Match Found 3
# ...

# %%
Zip_Word_Matches_Tags = list(zip(All_TedTalk_Tags, TTT_matches, TTT_list))

# %%
Word_Matches_Tag_df = pd.DataFrame(Zip_Word_Matches_Tags, columns = ["SearchWord","MatchesFound", "MatchedTags"])

# %%
Word_Matches_Tag_df.head()
# Out:
#     SearchWord  MatchesFound  \
# 0  3d printing             3
# 1     activism           149
# 2    addiction             5
# 3    adventure            48
# 4  advertising            10
#
#                                          MatchedTags
# 0  {'3d printing': ['3D printing,design,technolog...
# 1  {'activism': ['TED Brain Trust,film,culture,mu...
# 2  {'addiction': ['narcotics,addiction,culture,po...
# 3  {'adventure': ['Moon,mining,Planets,NASA,space...
# 4  {'advertising': ['advertising,consumerism,happ...

# %%
Word_Matches_Tag_df.to_csv("WMT.csv", index=True)

# %%
Zip_word_list = list(zip(All_TedTalk_Tags, TT_tags))
Word_list_df = pd.DataFrame(Zip_word_list, columns = ["SearchWord", "ListOfTags"])

# %%
Word_list_df.to_csv("wordlist.csv", index=True)

# %%
Zip_word_match_list = list(zip(All_TedTalk_Tags, TTT_matches, TT_tags))
Word_Matches_list_df = pd.DataFrame(Zip_word_match_list, columns = ["SearchWord","MatchesFound", "ListOfTags"])

# %%
Word_Matches_list_df.to_csv("WML.csv", index=True)

# %%
tedtalks.head()
# Out:
#    id       speaker                              headline  \
# 0   1       Al Gore           Averting the climate crisis
# 1   2     Amy Smith         Simple designs to save a life
# 2   3  Ashraf Ghani         How to rebuild a broken state
# 3   4    Burt Rutan  The real future of space exploration
# 4   5  Chris Bangle              Great cars are great art
#
#                                   url  \
# 0  http://www.ted.com/talks/view/id/1
# 1  http://www.ted.com/talks/view/id/2
# 2  http://www.ted.com/talks/view/id/3
# 3  http://www.ted.com/talks/view/id/4
# 4  http://www.ted.com/talks/view/id/5
#
#                                          description  \
# 0  With the same humor and humanity he exuded in ...
# 1  Fumes from indoor cooking fires kill more than...
# 2  Ashraf Ghani's passionate and powerful 10-minu...
# 3  In this passionate talk, legendary spacecraft ...
# 4  American designer Chris Bangle explains his ph...
#
# ...

# %% [markdown]
# ### Coursera

# %% [markdown]
# Not Used for ETL Project

# %% [markdown]
# ### Que Cera Cera

# %%
# File to Load 
coursera_data_to_load = "coursera-course-data/coursera-course-data.csv"
coursera_detail_to_load = "coursera-course-data/coursera-course-detail-data.csv"

# Read Data File and store into Pandas DataFrames
coursera_data = pd.read_csv(coursera_data_to_load)
coursera_detail = pd.read_csv(coursera_detail_to_load)

# %%
one = "'"
two = one + one
count_quote = one
print(two)
print(count_quote)
print(one)

# %%
tedtalks_more.head()

# %% [markdown]
# coursera_detail

# %%
coursera_detail.Rating.unique()

# %%
kind_of_rating = len(coursera_detail.Rating.unique())
print(f"How many different Kinds of Rating {kind_of_rating}")

# %%
coursera_detail.Difficulty.unique()

# %%
levels_of_Difficulty = len(coursera_detail.Difficulty.unique())
print(f"How many different Levels of Difficulty {levels_of_Difficulty}")

# %%
coursera_detail.Tags

# %%
coursera_detail.Tags.unique()

# %%
len(coursera_detail.Tags.unique())

# %%
coursera_tags =coursera_detail.Tags

# %%
coursera_tags

# %%
coursera_tags[0]

# %%
tags_set = set()

# %%
tags_set = set()
count_tags = 0

for tag_list in coursera_tags:
    if (tag_list):
        tags_set.add(tag_list)
        count_tags +=1

# %%
tags_set

# %%
count_tags

# %%
print(f"How many different Tags {count_tags}")

# %%
for s in tags_set:
    print(s)

# %%
print(s)

# %% [markdown]
# ### Grab the Search Phrase between single quotes

# %%
print(s)
new_phrase = ""
new_keyword = ""
keyword_list = []
phrase_list = []
keyword = new_keyword
phrase = new_phrase
blankspace = " "

for letter in s:
    open_braces = (letter == "[")
    closed_braces = (letter == "]")
    single_quote = (letter == "'")
    space = (letter==" ")
    comma = (letter == ",")

    
    alphabet = (not open_braces) and (not closed_braces) and (not single_quote) and (not comma) and (not space)
    if (open_braces):
            keyword_list = []
            phrase_list = []
            keyword = new_keyword
            phrase = new_phrase

            
 
    if (single_quote):
            if (keyword != new_keyword):
                keyword_list.append(keyword)
                phrase_list.append(phrase)
                keyword = new_keyword
                phrase = new_phrase
                

                

    if (space):
                if (keyword != new_keyword):
                    keyword_list.append(keyword)
                    keyword=new_keyword
                    phrase = phrase + blankspace


                
    if (closed_braces):
                #keyword_list.append(keyword)
                #phrase_list.append(phrase)
                keyword = new_keyword
                phrase = new_phrase
                open_quote = False
                closed_quote = True
    if (comma):
                #keyword_list.append(keyword)
                #phrase_list.append(phrase)       
                keyword = new_keyword
                phrase = new_phrase
                space_after_comma = True
            
            
    if (alphabet):
                keyword= keyword + letter
                phrase = phrase + letter
                space_after_comma = False

# %%
phrase_list

# %%
for phrase in phrase_list:
    print(phrase)

# %%
keyword_list

# %%
for key in keyword_list:
    print(key)

# %%
def find_phrase_list(s):
    
    
    new_phrase = ""
    new_keyword = ""
    keyword_list = []
    phrase_list = []
    keyword = new_keyword
    phrase = new_phrase


    for letter in s:
        open_braces = (letter == "[")
        closed_braces = (letter == "]")
        single_quote = (letter == "'")
        space = (letter==" ")
        comma = (letter == ",")

    
        alphabet = (not open_braces) and (not closed_braces) and (not single_quote) and (not comma) and (not space)
        if (open_braces):
            keyword_list = []
            phrase_list = []
            keyword = new_keyword
            phrase = new_phrase

            
 
        if (single_quote):
            if (keyword != new_keyword):
                keyword_list.append(keyword)
                phrase_list.append(phrase)
                keyword = new_keyword
                phrase = new_phrase
                

                

        if (space):
                if (keyword != new_keyword):
                    keyword_list.append(keyword)
                    keyword=new_keyword
                    phrase = phrase + blankspace


                
        if (closed_braces):
                #keyword_list.append(keyword)
                #phrase_list.append(phrase)
                keyword = new_keyword
                phrase = new_phrase
                open_quote = False
                closed_quote = True
        if (comma):
                #keyword_list.append(keyword)
                #phrase_list.append(phrase)       
                keyword = new_keyword
                phrase = new_phrase
                space_after_comma = True
            
            
        if (alphabet):
                keyword= keyword + letter
                phrase = phrase + letter
                space_after_comma = False
    
        
    
    
    
    return phrase_list

# %%
def find_keyword_list(s):
    
    
    new_phrase = ""
    new_keyword = ""
    keyword_list = []
    phrase_list = []
    keyword = new_keyword
    phrase = new_phrase


    for letter in s:
        open_braces = (letter == "[")
        closed_braces = (letter == "]")
        single_quote = (letter == "'")
        space = (letter==" ")
        comma = (letter == ",")

    
        alphabet = (not open_braces) and (not closed_braces) and (not single_quote) and (not comma) and (not space)
        if (open_braces):
            keyword_list = []
            phrase_list = []
            keyword = new_keyword
            phrase = new_phrase

            
 
        if (single_quote):
            if (keyword != new_keyword):
                keyword_list.append(keyword)
                phrase_list.append(phrase)
                keyword = new_keyword
                phrase = new_phrase
                

                

        if (space):
                if (keyword != new_keyword):
                    keyword_list.append(keyword)
                    keyword=new_keyword
                    phrase = phrase + blankspace


                
        if (closed_braces):
                #keyword_list.append(keyword)
                #phrase_list.append(phrase)
                keyword = new_keyword
                phrase = new_phrase
                open_quote = False
                closed_quote = True
        if (comma):
                #keyword_list.append(keyword)
                #phrase_list.append(phrase)       
                keyword = new_keyword
                phrase = new_phrase
                space_after_comma = True
            
            
        if (alphabet):
                keyword= keyword + letter
                phrase = phrase + letter
                space_after_comma = False
    
        
    
    
        
    return keyword_list

# %%
set_of_phrases = set()
for s in tags_set:
    phrase_list = find_phrase_list(s)
    for phrase in phrase_list:
        set_of_phrases.add(phrase)

# %%
set_of_phrases

# %%
set_of_keys = set()
for s in tags_set:
    keyword_list = find_keyword_list(s)
    for key in keyword_list:
        set_of_keys.add(key)

# %%
set_of_keys

# %%
len(set_of_keys)

# %% [markdown]
# ### Category

# %%
search_for = "Technology"

# %%
search_for = "cars"

# %%
print(f"Search for {search_for} in TedTalks")
found_match = False
search_match = True
for tag in tedtalks.tags:
    if (search_match):
        search_list = tag.split(",")
        if (search_for in search_list):
            search_match = found_match
            print(f"Ted Talks Match Found {tedtalks.speaker}")

# %% [markdown]
# ### Notes for me: Panda to DataBase to Panda

# %% [markdown]
# DROP TABLE IF EXISTS tt_table;
# CREATE TABLE tt_table(
#     tt_id integer NOT NULL,
#     tt_speaker character varying(255) NOT NULL,
#     tt_headline character varying(255) NOT NULL,
#     tt_url character varying (255) NOT NULL,
#     tt_desc character varying NOT NULL,
#     tt_transcript character varying(255),
#     tt_month_filmed integer,
#     tt_year_filmed integer,
#     tt_event character varying(255),
#     tt_duration character varying(8),
#     tt_date_published DATE,
#     tt_tags character varying NOT NULL
# );
#
# COPY tt_table FROM '/Applications/PostgreSQL 12/etl_data/data/QueryResult.csv' DELIMITER ',' CSV HEADER;
# SELECT * FROM tt_table;

# %% [markdown]
# --Notes to connect to PostGres -- from sqlalchemy import create_engine from config import username, password engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/online_ed') con = engine.connect()
# conn = "postgres:postgres@localhost:5432/online_ed" engine = create_engine(f'postgresql://{conn}')
# DataFrame.to_sql(name='YouTubeVideos', con=engine, if_exists='replace', index=False)
# --Syntax-- df = DataFrame(Cars, columns= ['Brand', 'Price']) df.to_sql('CARS', conn, if_exists='replace', index = False)
# c.execute('''
# SELECT * FROM CARS ''')
# for row in c.fetchall(): print (row)
# ---My Notes for AutoMap --- ---To Reflect a DataBase into Panda --- from sqlalchemy.ext.automap import automap_base from sqlalchemy.orm import Session from sqlalchemy import create_engine
# Base = automap_base()
# Case: Engine, suppose it has two tables 'user' and 'address' set up engine = create_engine("sqlite:///mydatabase.db")
# Reflect the tables Base.prepare(engine, reflect=True)
# Mapped classes are now created with names by default Matching that of the table name. User = Base.classes.user Address = Base.classes.address
# session = Session(engine)
# Rudimentary relationships are produced session.add(Address(email_address="foo@bar.com", user=User(name="foo"))) session.commit()
# Collection-based relationships are by default named "_collection" print (u1.address_collection)
# --- How to take a Screen Shot in Python -- import pyautogui
# myScreenshot = pyautogui.screenshot() myScreenshot.save(r'Path to save screenshot\file name.png') Step 1: pip install pyautogui (Decide where to save the Picture: example: C:\Users\Ron\Desktop\Test\screenshot1.png) More Details at: https://datatofish.com/screenshot-python/
